# %%
import sys
print('python', sys.version)

import numpy as np
print('numpy', np.__version__)

import pandas as pd
print('pandas', pd.__version__)

import matplotlib as mpl
print('matplotlib', mpl.__version__)

import matplotlib.pyplot as plt

# # 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# plt.rc("font", family="Malgun Gothic") # 한글표시 (window)
plt.rc("font", family="AppleGothic") # 한글표시 (mac)
plt.rc("axes", unicode_minus=False) # x,y축 (-)부호 표시
# Out:
# python 3.10.13 (main, Mar 12 2024, 15:59:23) [Clang 15.0.0 (clang-1500.1.0.2.5)]
# numpy 1.26.4
# pandas 2.2.3
# matplotlib 3.8.3

# %%
##################################################
############### 문제 풀기 전 주의사항 ##############
##################################################

# 시험시간 내 인터넷 사용 금지, 시험문제 다운로드, 업로드 시에만 가능
# (시험 중, 핸드폰이나 인터넷 사용을 포함한 부정행위 적발시 0점 처리).

# ipynb, html 시험 파일, 데이터를 모두 다운 받고,
# ipynb 시험 파일은 파일명 수정 -> dv화_20231234_홍길동.ipynb.

# html 파일의 실행결과를 참고하여, ipynb 파일의 #=== 코드작성 ===# 부분에 코드를 작성하여
# 프로그램을 완성 (ipynb파일의 실행결과는 코드 작성과정에서 사라질 수 있음).

# 맨 위의 셀을 우선 실행.
# 랜덤 값을 입력으로하는 문제는 주어진 실행결과와 다른 실행결과가 나올 수 있음.
# 문제에 주어진 코드는 수정 불가.

# 시험 도중 anaconda prompt (검은창) 지우지 말것.
# 갑자기 컴퓨터에 문제가 생길수 있으니, 시험 중간중간에 파일 저장 (crtl+s) 할 것.

# 시험이 끝나면 실행결과를 모두 확인하고 난 후에, 저장 하고 제출
# (작성한 ipynb 시험 파일(dv화_20231234_홍길동.ipynb)을  "캔버스 --> 과제 --> 중간고사" 에 업로드).

# %% [markdown]
# * c: condition (조건)
# * h: hint

# %% [markdown]
# ## 문제1

# %%
# 그려진 네모의 각 중간점을 이은 마름모 모양의 네모를 그리시오

# c1) 마커는 네모로 함 (색깔은 채점과 무관)

fig=plt.figure(figsize=(5,5), dpi=100)
ax =fig.subplots()

X1=[100,100,120,120,100]
Y1=[100,120,120,100,100]
_=ax.plot(X1,Y1, 's-')

## 코드작성
X2 = [100,110,120,110,100]
Y2 = [110,100,110,120,110]
_=ax.plot(X2,Y2, 's-')

# %% [markdown]
# ## 문제2

# %%
# tue_p2.txt 파일을 읽은 data가 있다.
# 세 가지 색깔의 해당 column들이, col_red, col_green, col_blue에 담겨있다.
# 각 column을 해당 color로 plot하시오

# c1) for loop을 사용
# c2) col_red, col_green, col_blue의 column들은 채점시 변경 가능

fig=plt.figure(figsize=(6,4), dpi=100)
ax=fig.subplots()

data=pd.read_table('data/tue_p2.txt', sep='\t')
data.head()

col_red=['Y1','Y4','Y7']
col_green=['Y2','Y5', 'Y8']
col_blue=['Y3','Y6', 'Y9', 'Y10']
color_column_dic = {'r':col_red,'g':col_green,'b':col_blue}

## 코드작성
for color in ['r','g','b']:
    for col in color_column_dic[color]:
        _=ax.plot(data[col],color=color)
# Out:
#          Y1         Y2         Y3         Y4         Y5         Y6         Y7  \
# 0  2.779177  12.117801  23.514451  31.331194  40.888278  51.899831  63.355372
# 1  3.463164  14.148258  19.409160  29.387509  41.698510  53.240285  62.716212
# 2  3.534131  11.210939  18.426470  27.416234  39.174087  51.620527  62.457048
# 3  0.871218  12.429485  20.626322  27.509604  40.436135  49.510085  63.292294
# 4  0.389034   7.764271  15.806704  31.996709  42.038541  49.767113  58.589493
#
#           Y8         Y9        Y10
# 0  66.726906  77.976830  89.247948
# 1  70.305915  81.465146  92.972199
# 2  69.660125  79.960002  91.139650
# 3  70.000918  77.562145  87.083071
# 4  72.147415  79.705393  91.337351

# %% [markdown]
# ## 문제3

# %%
# 아래 두 개의 분포에서 샘플을 1000개씩 각각 생성하고, 각 샘플에 대하여 hisgram으로 아래와 같이 나타내시오
# 분포 1) 평균 4 표준편차 1인 정규분포 (normal distribution)
# 분포 2) 0~2 까지의 범위를 갖는 uniform distribution

# c1) hist 함수 호출의 순서 주의
# c2) bins=15, edgecolor='k'

fig=plt.figure(figsize=(5,4), dpi=100)
ax =fig.subplots()

## 코드작성
data1 = np.random.randn(1000) * 1 + 4
data2 = np.random.rand(1000) * 2
_=ax.hist(data1,bins=15,edgecolor='k')
_=ax.hist(data2,bins=15,edgecolor='k')

# %% [markdown]
# ## 문제4

# %%
# 주어진 X를 가지고 아래와 같은 pie 그래프를 그리시오

fig=plt.figure(figsize=(4,4), dpi=100)
ax =fig.subplots()

X=np.arange(5)*0.02
X

## 코드작성
ax.pie(X, normalize=False) # 이거 안함
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08])
# ([<matplotlib.patches.Wedge at 0x127774790>,
# ...
#  [Text(1.1, 0.0, ''),
#   Text(1.0978294013681003, 0.06906956994045162, ''),
#   Text(1.0654414787782402, 0.27355886989611045, ''),
#   Text(0.9287607255021239, 0.589409462737721, ''),
#   Text(0.5894094953465412, 0.928760704807937, '')])

# %% [markdown]
# ## 문제5

# %%
# 주어진 Series를 가지고 bar graph를 그리시오

# c1) axes plot을 사용 (pandas plot 사용시 감점)
# h1) X tick label에 유의

fig=plt.figure(figsize=(5,3), dpi=100)
ax =fig.subplots()

sr1=pd.Series([1,4,2,5,3], index=list('abcde'))
sr1
## 코드작성
_=ax.bar(sr1.index,sr1.values)
# _=ax.set_xticks(range(len(sr1.index)),list(sr1.index))
# Out:
# a    1
# b    4
# c    2
# d    5
# e    3
# dtype: int64

# %% [markdown]
# ## 문제6

# %%
# tue_dat2.txt 파일을 읽은 data (dataframe)를 아래와 같이 다중막대그래프로 나타내시오

# c1) 각 열의 값들을 하나의 bar 그룹으로 함
# c2) axe plot을 사용
# c3) for loop 사용
# c4) width=1, bar그룹 사이에 간격=1
# h1) 맨 아래의 xtick setting 코드는 무시해도 됨

fig=plt.figure(figsize=(7,3), dpi=100)
ax=fig.subplots()

data=pd.read_table('data/tue_p6.txt',sep='\t', index_col=0)
data

## 코드작성
X = np.arange(len(data.columns))
for i, row in enumerate(data.index):
    _=ax.bar(X+i*0.2,data.loc[row],width=0.2)
_=ax.set_xticks([0.3, 1.3, 2.3],labels=data.columns)
# Out:
#      kia  hyundai  bmw
# 1st   76       54   40
# 2nd   81       47   55
# 3rd   84       42   67
# 4th   91       35   80

# %% [markdown]
# ## 문제7

# %%
# shape=1, scale=2인 gamma 분포에서 1000개의 값을 뽑아 히스토그램으로 ax1에 나타내었다.
# 위와 같은 분포에서 500개 값을 뽑아 그들의 '평균'이 m1이라고 할 때,
# m1의 값 3000개를 구하여 히스토그램으로 ax2에 나타내시오

# c1) 샘플 사이즈와 평균값의 개수에 주의
# c2) for loop 사용 ''불가''
# h1) bins=20, edgecolor='k'

fig=plt.figure(figsize=(10,3), dpi=100)
ax1, ax2=fig.subplots(1,2)

data=np.random.gamma(1,2,size=1000)

_=ax1.hist(data, bins=20, edgecolor='k')

## 코드작성
data = np.random.gamma(1,2,size=(3000,500))
m1 = data.mean(axis=0)
_=ax2.hist(m1, bins=20, edgecolor='k')

# %% [markdown]
# ## 문제8

# %%
# 0<X<4pi 구간에 일정한 간격을 갖는 200개의 점들에 대해서, Y=sin(X)를 scatter 하는데,
# 그림과 같이 y가 0.5 보다 큰 경우는 빨간색, 그렇지 않은 경우는 파란색으로 scatter 하시오

# c1) color 파라미터에 list 형태의 값을 받아, scatter 함수를 한 번 만 사용
# h1) scatter 함수의 s=10
fig=plt.figure(figsize=(7,4), dpi=100)
ax =fig.subplots()

## 코드작성
X = np.linspace(0,4*np.pi,200)
Y = np.sin(X)
color_list = np.where(Y>0.5, 'r','b')
_=ax.scatter(X,Y,color=color_list, s=10)

# %% [markdown]
# ## 문제9

# %%
# 주어진 df는 세 개의 class(0,1,2)를 가지고 있다.
# f1,f2,f3 세개의 feature 중에
# class0 그룹의 평균과 class1 그룹의 평균의 차이(=df01)가
# class1 그룹의 평균과 class2 그룹의 평균의 차이(=df12)보다 큰
# feature를 구하는 코드이다
# df01과 df12에 알맞은 값이 들어가도록 코드의 중간 부분을 채우시오

# h1) 차이이기 때문에 df01, df12에 들어가는 모든 값은 0 이상임

df = pd.read_table('data/tue_p9.txt', sep='\t')
df.head()

## 코드작성
df01 = abs(df[df['class'] == 0].mean(axis=0) - df[df['class']==1].mean(axis=0))
df12 = abs(df[df['class'] == 1].mean(axis=0) - df[df['class']==2].mean(axis=0))
df01
df12
diff=df01-df12
diff.loc[diff>0].index
# Out:
#          f1        f2        f3  class
# 0  1.150744  8.181925  5.679369      0
# 1  2.454496  4.786803  1.675637      2
# 2  0.389527  0.572960  1.472833      0
# 3  3.511859  8.844367  0.363331      2
# 4  4.726607  2.068217  8.378356      1
# f1       4.739318
# f2       0.203844
# f3       0.225303
# class    1.000000
# dtype: float64
# f1       2.075968
# f2       0.484994
# f3       0.968589
# class    1.000000
# dtype: float64
# Index(['f1'], dtype='object')

# %% [markdown]
# ## 문제10

# %%
# 각 50개의 값을 갖는 X,Y를 scatter 하는데,
# y의 좌표가 0 이상인 경우에는 marker '^', color 'r',
# y의 좌표가 0 미만인 경우에는 marker 'v', color 'b' 로 하시오
# c1) scatter 함수를 두 번만 사용

fig=plt.figure(figsize=(6,5), dpi=100)
ax=fig.subplots()

d1=np.random.normal(size=(50,2))
X=d1[:,0]
Y=d1[:,1]

## 코드작성
for condition, marker, color in zip([Y >= 0, Y < 0],['^','v'],['r','b']):
    _=ax.scatter(X[condition], Y[condition], marker=marker, c=color, edgecolors='k')

# %% [markdown]
# ## 문제11

# %%
# data의 'sep_len'를 x로, 'sep_wid'를 y로하여 scatter 하는데, 아래의 조건을 만족하면서 scatter 하시오
# c1) Iris-setosa는 마커모양 '*', size=200
# c2) Iris-versicolor는 마커모양 'o', size=150
# c3) Iris-virginica는 마커모양 's', size=20
# c4) 모든 마커의 color: 'y', edgecolor: 'k'


fig=plt.figure(figsize=(5,5), dpi=100)
ax=fig.subplots()

data = pd.read_table('data/tue_p11.txt', sep=',')
data
## 코드작성
marker_size_dic = {'Iris-setosa': {'marker':'*','size':200},'Iris-versicolor':{'marker':'o','size':150},'Iris-virginica':{'marker':'s','size':20}}

for cls, marker_size in marker_size_dic.items():
    _data = data[data['name']==cls]
    _=ax.scatter(_data['sep_len'], _data['sep_wid'], marker=marker_size['marker'], s=marker_size['size'], c='y', edgecolor='k')
# Out:
#      sep_len  sep_wid  pet_len  pet_wid            name
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 문제12

# %%
# 주어진 df의 data를 가지고 아래와 같이 bar graph를 그리시오
# c1) height: price
# c2) color: price가 20 이상 => y, price가 20 미만 => g 
# c3) hatch: station이 'Y' => *, station이 'N' => '/' 


### 아직 안 배움

fig=plt.figure(figsize=(6,3), dpi=100)
ax=fig.subplots()

df=pd.read_table('data/tue_p12.txt', sep='\t')
df=df.drop(columns=['x','y']).tail(10)
df['station']=df['station'].replace({'o':'Y', 'x':'N'})
df.index=list('ABCDEFGHIJ')
df

## 코드작성
_=ax.bar(df.index, df['price'], color=np.where(df['price']>=20,'y','g'), hatch=np.where(df['station'] == 'Y', '*', '/'))
# Out:
#    price station
# A     27       Y
# B     10       Y
# C     21       Y
# D     18       Y
# E     20       Y
# F     16       N
# G     14       N
# H     29       N
# I     23       Y
# J     23       Y

# %% [markdown]
# ## 문제13

# %%
# 주어진 d1의 column별로 boxplot을 그리는데
# 각 column의 평균이 작은순서에서 큰순서로 boxplot을 그리시오

# c1) pandas plot 사용
# h1) 아래 셀의 hint를 참고

fig=plt.figure(figsize=(6,3), dpi=100)
ax=fig.subplots()
d1=pd.read_table('data/tue_p13.txt', sep='\t')
d1

## 코드작성
# 슬라이싱으로 박스플롯 순서 바꿈
d1_cols = d1.mean(axis=0).sort_values().index
d1[d1_cols].plot.box(ax=ax)
# Out:
#            A         B         C         D
# 0  -0.373578  3.018945  0.717001  8.034292
# 1  -0.439556  4.235749  0.029124  6.465629
# 2   2.020907  2.438185  2.461766  6.363834
# 3   0.905671  2.919177 -0.422454  4.974867
# 4   1.549187  4.074490 -1.034272  6.590412
# ..       ...       ...       ...       ...
# 95  0.373064  5.045525  1.479558  5.641818
# 96 -0.902394  5.032298  1.279740  5.351727
# 97  1.478827  4.789166  1.061248  6.416353
# 98 -0.940119  4.741578  3.810924  5.729022
# 99 -1.033503  4.856876  1.357581  6.021085
#
# [100 rows x 4 columns]
# <Axes: >

# %%
## hint
df1=pd.DataFrame({'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]})
df1
column_list=['c','a','b']
df1[column_list]
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#    c  a  b
# 0  7  1  4
# 1  8  2  5
# 2  9  3  6
